# %%
import pandas as pd
df=pd.read_csv("Titanic-Dataset.csv")

# %%
df.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
# 20          912         0       1
# 21          913         0       3
# 22          914         1       1
# 23          915         0       1
# 24          916         1       1
# 25          917         0       3
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])
df["Cabin"] = df["Cabin"].fillna("Unknown")

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
Q1 = df["Age"].quantile(0.25)
Q3 = df["Age"].quantile(0.75)
IQR = Q3 - Q1
df = df[(df["Age"] >= Q1 - 1.5 * IQR) & (df["Age"] <= Q3 + 1.5 * IQR)]

# %%
df[df["Age"] > 18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 6            898         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# ...

# %%
df[df["Sex"] == "female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df[df["Pclass"] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 11           903         0       1
# 12           904         1       1
# 14           906         1       1
# 22           914         1       1
# 23           915         0       1
# ..           ...       ...     ...
# 403         1295         0       1
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  27.0      0
# 23                     Williams, Mr. Richard Norris II    male  21.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.443182
# 2    0.317647
# 3    0.320574
# Name: Survived, dtype: float64

# %%
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    1.0
# male      0.0
# Name: Survived, dtype: float64

# %%
print("Total Passengers:", len(df))
print("Survived:", df["Survived"].sum())
print("Not Survived:", (df["Survived"] == 0).sum())
print("Survival Rate:", df["Survived"].mean())
# Out:
# Total Passengers: 382
# Survived: 133
# Not Survived: 249
# Survival Rate: 0.3481675392670157

# %%
import matplotlib.pyplot as plt
df["Pclass"].value_counts().plot(kind="bar")
plt.title("Passenger Class Distribution")
plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.show()

# %%
df["Age"].head(20).plot(kind="line")
plt.title("Age Trend")
plt.xlabel("Passenger")
plt.ylabel("Age")
plt.show()

# %%
plt.hist(df["Age"], bins=10)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.scatter(df["Age"], df["Fare"])
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# # EDA Report
#
# 1. The Titanic dataset was successfully loaded.
# 2. Missing values were identified and handled using median, mode, and "Unknown".
# 3. Duplicate records were removed.
# 4. Outliers in the Age column were detected and treated using the IQR method.
# 5. Passenger data was filtered based on age, gender, and passenger class.
# 6. GroupBy analysis was performed on passenger class and gender.
# 7. Survival statistics were calculated.
# 8. Bar chart, Line chart, Histogram, and Scatter plot were created.
# 9. Female passengers had a higher survival rate than male passengers.
# 10. First-class passengers showed a better survival rate compared to other classes.
